# %% [markdown]
# # Analyze the data

# %% [markdown]
# # 1. Imports

# %% [markdown]
# ## 1.1 Packages

# %%
import pandas as pd

# %% [markdown]
# ## 1.2 Options

# %% [markdown]
# ## 1.3 Datasets

# %%
df_train = pd.read_parquet("../data/01_raw/jane-street-real-time-market-data-forecasting/train.parquet")
